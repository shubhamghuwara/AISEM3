# %% [markdown]
# Shubham Jain Assignment 1

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6f200bc5-23e6-41e3-a9da-a8a76edab080" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f200bc5-23e6-41e3-a9da-a8a76edab080">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (2).json
# {'kaggle.json': b'{"username":"shubhamghuwara","key":"c2cc1d12836463c57027fd1608651242"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list

# %%
# !kaggle competitions download -c home-credit-default-risk
# Out:
# ...
# application_test.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# POS_CASH_balance.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# credit_card_balance.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# HomeCredit_columns_description.csv: Skipping, found more recently modified local copy (use --force to force download)
# bureau_balance.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# application_train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# installments_payments.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# ...

# %%
! unzip \*.zip
# Out:
# Archive:  application_train.csv.zip
# replace application_train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-1398a0ff040c> in <module>()
# ----> 1 get_ipython().system(' unzip \\*.zip ')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
# ...

# %%
import numpy as np
import pandas as pd

import os

import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(os.listdir("/content/"))
# Out:
# ['.config', 'application_train.csv', 'application_train.csv.zip', 'installments_payments.csv.zip', 'HomeCredit_columns_description.csv', 'bureau.csv', 'bureau_balance.csv', 'previous_application.csv', 'kaggle (2).json', 'bureau.csv.zip', 'sample_submission.csv', 'application_test.csv.zip', 'kaggle.json', 'credit_card_balance.csv.zip', 'credit_card_balance.csv', 'POS_CASH_balance.csv', 'application_test.csv', 'POS_CASH_balance.csv.zip', 'bureau_balance.csv.zip', 'previous_application.csv.zip', 'installments_payments.csv', 'kaggle (1).json', 'sample_data']

# %%
app_train = pd.read_csv('/content/application_train.csv')
print('Training data shape: ', app_train.shape)
app_train.head()
# Out:
# Training data shape:  (307511, 122)
#    SK_ID_CURR  TARGET  ... AMT_REQ_CREDIT_BUREAU_QRT AMT_REQ_CREDIT_BUREAU_YEAR
# 0      100002       1  ...                       0.0                        1.0
# 1      100003       0  ...                       0.0                        0.0
# 2      100004       0  ...                       0.0                        0.0
# 3      100006       0  ...                       NaN                        NaN
# 4      100007       0  ...                       0.0                        0.0
#
# [5 rows x 122 columns]

# %%
app_test = pd.read_csv('/content/application_test.csv')
print('Testing data shape: ', app_test.shape)
app_test.head()
# Out:
# Testing data shape:  (48744, 121)
#    SK_ID_CURR  ... AMT_REQ_CREDIT_BUREAU_YEAR
# 0      100001  ...                        0.0
# 1      100005  ...                        3.0
# 2      100013  ...                        4.0
# 3      100028  ...                        3.0
# 4      100038  ...                        NaN
#
# [5 rows x 121 columns]

# %%
app_test.describe()
# Out:
#           SK_ID_CURR  ...  AMT_REQ_CREDIT_BUREAU_YEAR
# count   48744.000000  ...                42695.000000
# mean   277796.676350  ...                    1.983769
# std    103169.547296  ...                    1.838873
# min    100001.000000  ...                    0.000000
# 25%    188557.750000  ...                    0.000000
# 50%    277549.000000  ...                    2.000000
# 75%    367555.500000  ...                    3.000000
# max    456250.000000  ...                   17.000000
#
# [8 rows x 105 columns]

# %%
app_test.shape
# Out:
# (48744, 121)

# %% [markdown]
#  EDA
#
#  Looking at the target variable
#  0 = loan paid on time
#  1 = loan not paid on time

# %%
app_train["TARGET"].value_counts()
# Out:
# 0    282686
# 1     24825
# Name: TARGET, dtype: int64

# %%
app_train["TARGET"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Look at missing values

# %%
app_train.isnull().sum()
# Out:
# SK_ID_CURR                        0
# TARGET                            0
# NAME_CONTRACT_TYPE                0
# CODE_GENDER                       0
# FLAG_OWN_CAR                      0
#                               ...
# AMT_REQ_CREDIT_BUREAU_DAY     41519
# AMT_REQ_CREDIT_BUREAU_WEEK    41519
# AMT_REQ_CREDIT_BUREAU_MON     41519
# AMT_REQ_CREDIT_BUREAU_QRT     41519
# AMT_REQ_CREDIT_BUREAU_YEAR    41519
# Length: 122, dtype: int64

# %%
numerical = app_test.select_dtypes(["float64","int64"])

# %%
len(numerical.columns)
# Out:
# 105

# %%
for cols in numerical:
  app_train[cols] = app_train[cols].fillna(app_train.groupby("TARGET")[cols].transform("mean"))

# %%
categorical = app_train.select_dtypes('object')

# %%
len(categorical.columns)
# Out:
# 16

# %%
for cols in categorical:
  app_train[cols] = app_train.groupby('TARGET')[cols].apply(lambda x: x.fillna(x.value_counts().idxmax() if x.value_counts().max() >=1 else mode , inplace = False))

# %%
for cols in app_train.columns:
  print("{}:{}".format(cols, app_train[cols].isna().sum()))
# Out:
# SK_ID_CURR:0
# TARGET:0
# NAME_CONTRACT_TYPE:0
# CODE_GENDER:0
# FLAG_OWN_CAR:0
# FLAG_OWN_REALTY:0
# CNT_CHILDREN:0
# AMT_INCOME_TOTAL:0
# AMT_CREDIT:0
# AMT_ANNUITY:0
# AMT_GOODS_PRICE:0
# NAME_TYPE_SUITE:0
# NAME_INCOME_TYPE:0
# NAME_EDUCATION_TYPE:0
# NAME_FAMILY_STATUS:0
# NAME_HOUSING_TYPE:0
# REGION_POPULATION_RELATIVE:0
# DAYS_BIRTH:0
# DAYS_EMPLOYED:0
# DAYS_REGISTRATION:0
# DAYS_ID_PUBLISH:0
# OWN_CAR_AGE:0
# FLAG_MOBIL:0
# FLAG_EMP_PHONE:0
# FLAG_WORK_PHONE:0
# FLAG_CONT_MOBILE:0
# FLAG_PHONE:0
# FLAG_EMAIL:0
# OCCUPATION_TYPE:0
# CNT_FAM_MEMBERS:0
# REGION_RATING_CLIENT:0
# REGION_RATING_CLIENT_W_CITY:0
# WEEKDAY_APPR_PROCESS_START:0
# HOUR_APPR_PROCESS_START:0
# REG_REGION_NOT_LIVE_REGION:0
# REG_REGION_NOT_WORK_REGION:0
# LIVE_REGION_NOT_WORK_REGION:0
# REG_CITY_NOT_LIVE_CITY:0
# REG_CITY_NOT_WORK_CITY:0
# LIVE_CITY_NOT_WORK_CITY:0
# ORGANIZATION_TYPE:0
# EXT_SOURCE_1:0
# EXT_SOURCE_2:0
# EXT_SOURCE_3:0
# APARTMENTS_AVG:0
# BASEMENTAREA_AVG:0
# ...

# %% [markdown]
# Look at column data types

# %%
app_train = pd.get_dummies(app_train)


print('Training Features shape: ', app_train.shape)
# Out:
# Training Features shape:  (307511, 245)

# %%
X=app_train.drop(['TARGET','SK_ID_CURR'],axis=1)
Y=app_train['TARGET']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=123)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

classifier=LogisticRegression(max_iter=1000)
classifier.fit(X_train,Y_train)
pred=classifier.predict(X_test)
print(classification_report(pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96     61503
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.92     61503
#    macro avg       0.50      0.46      0.48     61503
# weighted avg       1.00      0.92      0.96     61503
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier().fit(X_train,Y_train)
predictions=rf.predict(X_test)
print(classification_report(predictions,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56866
#            1       0.92      1.00      0.96      4637
#
#     accuracy                           0.99     61503
#    macro avg       0.96      1.00      0.98     61503
# weighted avg       0.99      0.99      0.99     61503

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier(objective='binary:logistic')
xgb.fit(X_train,Y_train)
predictions=xgb.predict(X_test)
print(classification_report(predictions,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56662
#            1       0.97      1.00      0.98      4841
#
#     accuracy                           1.00     61503
#    macro avg       0.98      1.00      0.99     61503
# weighted avg       1.00      1.00      1.00     61503

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(X_train, Y_train)
predictions = nb.predict(X_test)

print(classification_report(predictions, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95     61104
#            1       0.00      0.05      0.01       399
#
#     accuracy                           0.91     61503
#    macro avg       0.50      0.48      0.48     61503
# weighted avg       0.99      0.91      0.95     61503
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95     61104
#            1       0.00      0.05      0.01       399
#
#     accuracy                           0.91     61503
#    macro avg       0.50      0.48      0.48     61503
# weighted avg       0.99      0.91      0.95     61503
